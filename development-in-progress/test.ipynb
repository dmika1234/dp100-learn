# %%
from pathlib import Path, os
target = "dp100-learn"
p = Path.cwd()
print(f"Starting working directory: {p}")
while p.name != target and p.parent != p:
    p = p.parent
os.chdir(p)
print("Changed working directory to:", p)
# Out:
# Starting working directory: c:\Users\dmika\DEV\Projects-local\dp100-learn
# Changed working directory to: c:\Users\dmika\DEV\Projects-local\dp100-learn

# %%
from pathlib import Path
import sys
from utils.consts import DEV_ENVIRONMENT, AZUREML_SUBSCRIPTION_ID as subscription_id, AZUREML_RESOURCE_GROUP as resource_group, AZUREML_WORKSPACE_NAME as workspace_name
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential
from azure.ai.ml import MLClient
from azure.core.exceptions import ResourceNotFoundError
import warnings
import os

# %%
from pathlib import Path
import sys
from utils.consts import DEV_ENVIRONMENT, AZUREML_SUBSCRIPTION_ID as subscription_id, AZUREML_RESOURCE_GROUP as resource_group, AZUREML_WORKSPACE_NAME as workspace_name
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential
from azure.ai.ml import MLClient
from azure.core.exceptions import ResourceNotFoundError
import warnings

def get_azureml_client():
    """
    Get an Azure ML Client based on the current environment.
    - If running on Azure ML compute, use workspace config.
    - If running locally, use explicit parameters.
    - If the workspace does not exist, warn and return an MLClient without a workspace.
    """

    # Try DefaultAzureCredential, fall back to InteractiveBrowserCredential if needed
    try:
        credential = DefaultAzureCredential()
        credential.get_token("https://management.azure.com/.default")
    except Exception:
        credential = InteractiveBrowserCredential()

    try:
        if 'compute' in DEV_ENVIRONMENT.lower():
            ml_client = MLClient.from_config(credential=credential)
        else:
            ml_client = MLClient(
                credential=credential,
                subscription_id=subscription_id,
                resource_group_name=resource_group,
                workspace_name=workspace_name
            )
        # Validate workspace existence by calling a simple method
        _ = ml_client.workspaces.get(workspace_name)
    except ResourceNotFoundError:
        warnings.warn(
            f"⚠️ Azure ML workspace '{workspace_name}' not found. "
            "Creating MLClient without a workspace context."
        )
        ml_client = MLClient(
            credential=credential,
            subscription_id=subscription_id,
            resource_group_name=resource_group
        )
    except Exception as e:
        warnings.warn(
            f"⚠️ Unable to connect to Azure ML workspace: {e}. "
            "Returning client without workspace context."
        )
        ml_client = MLClient(
            credential=credential,
            subscription_id=subscription_id,
            resource_group_name=resource_group
        )

    return ml_client

# %%
get_azureml_client()
# Out:
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# C:\Users\dmika\AppData\Local\Temp\ipykernel_18684\2411504138.py:37: UserWarning: ⚠️ Azure ML workspace 'azure-ml-dev-ws' not found. Creating MLClient without a workspace context.
#   warnings.warn(
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# MLClient(credential=<azure.identity._credentials.default.DefaultAzureCredential object at 0x000001C2F94999F0>,
#          subscription_id=a1267753-4c98-48c1-a8e9-9c7169202ffd,
#          resource_group_name=azure-ml-dev-rg,
#          workspace_name=None)

# %%
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential
from azure.ai.ml import MLClient
from azure.core.exceptions import ResourceNotFoundError
import warnings
import os

import os
# Here we set the working directory to the project root to ensure imports work correctly
your_project_path = "C:/Users/dmika/DEV/Projects-local/dp100-learn/"
os.chdir(your_project_path)
from utils.azureml_utils import *



project_dir = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
if str(project_dir) not in sys.path:
    sys.path.insert(0, str(project_dir))
from utils.consts import DEV_ENVIRONMENT, AZUREML_SUBSCRIPTION_ID as subscription_id, AZUREML_RESOURCE_GROUP as resource_group, AZUREML_WORKSPACE_NAME as workspace_name
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential
from azure.ai.ml import MLClient
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 15
#      10 os.chdir(your_project_path)
#      11 from utils.azureml_utils import *
# ---> 15 project_dir = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
#      16 if str(project_dir) not in sys.path:
#      17     sys.path.insert(0, str(project_dir))
#
# NameError: name '__file__' is not defined

# %%
os.gecwd()

# %%
# Out:
# WindowsPath('C:/Users/dmika/DEV/Projects-local/dp100-learn')

# %%
# Set working directory to the project root
from pathlib import Path
current_dir = Path.cwd()
target = "dp100-learn"
if current_dir == target:
    print("Changed directory to:", os.getcwd())
    break
for parent in current_dir.parents:
    if parent.name == target:
        os.chdir(parent)
        print("Changed directory to:", os.getcwd())
        break
else:
    print(f"'{target}' not found in current path.")
# Out:
# 'dp100-learn' not found in current path.
