# %%
import os
from dotenv import load_dotenv
# Add references
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from openai import AzureOpenAI

# %%
load_dotenv()
project_endpoint = os.getenv("PROJECT_ENDPOINT")
model_deployment =  os.getenv("MODEL_DEPLOYMENT")
# Initialize the project client
project_client = AIProjectClient(            
         credential=DefaultAzureCredential(
             exclude_environment_credential=True,
             exclude_managed_identity_credential=True
         ),
         endpoint=project_endpoint,
     )

# %%
# Get a chat client
openai_client = project_client.inference.get_azure_openai_client(api_version="2024-10-21")

# %%
# Initialize prompt with system message
prompt = [
         {"role": "system", "content": "You are a helpful AI assistant that answers questions."}
     ]

# %%
# Get a chat completion
prompt.append({"role": "user", "content": input_text})
response = openai_client.chat.completions.create(
         model=model_deployment,
         messages=prompt)
completion = response.choices[0].message.content
print(completion)
prompt.append({"role": "assistant", "content": completion})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Get a chat completion
# ----> 2 prompt.append({"role": "user", "content": input_text})
#       3 response = openai_client.chat.completions.create(
#       4          model=model_deployment,
#       5          messages=prompt)
#       6 completion = response.choices[0].message.content
#
# NameError: name 'input_text' is not defined
